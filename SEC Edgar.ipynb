# %%
from sec_edgar_downloader import Downloader

# Initialize downloader with required parameters
dl = Downloader(
    company_name="University of Central Florida",
    email_address="ja874524@ucf.edu"
)

# Download 10-K filings for Marriott International (ticker: MAR), or CIK
dl.get("20-F", "0001724755")

# Files will be saved locally in the "sec-edgar-filings" directory
# Out:
# 7
